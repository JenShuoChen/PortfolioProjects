# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
from mplsoccer import Pitch

# %%
df = pd.read_csv('/Users/jen-shuo/Desktop/Data portfolio/Football/EPL2021-2022.csv')
df.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# 1     1.93     2.10     1.79
# 2     2.19     1.79     2.12
# 3     1.93     2.06     1.82
# 4     1.90     2.03     1.86
#
# [5 rows x 106 columns]

# %% [markdown]
# # Pythagorean Expectation and Winning Rate

# %%
# Set result Home win and Away win to 1, Draw to 0.5
df['hwinvalue']=np.where(df['FTR']=='H',1,np.where(df['FTR']=='D',.5,0))
df['awinvalue']=np.where(df['FTR']=='A',1,np.where(df['FTR']=='D',.5,0))
df['count']=1

# %%
# Create a df for home team performance
home = df.groupby(['HomeTeam', 'Div'])[['count', 'hwinvalue', 'FTHG', 'FTAG']].sum().reset_index()
home = home.rename(columns={'HomeTeam': 'team', 'count': 'Ph', 'FTHG': 'FTHGh', 'FTAG': 'FTAGh'})
home.head()
# Out:
#           team Div  Ph  hwinvalue  FTHGh  FTAGh
# 0      Arsenal  E0  19       14.0     35     17
# 1  Aston Villa  E0  19        8.5     29     29
# 2    Brentford  E0  19        8.5     22     21
# 3     Brighton  E0  19        8.5     19     23
# 4      Burnley  E0  19        8.0     18     25

# %%
# Create a df for away team performance
away = df.groupby(['AwayTeam'])[['count','awinvalue', 'FTHG','FTAG']].sum().reset_index()
away = away.rename(columns={'AwayTeam':'team','count':'Pa','FTHG':'FTHGa','FTAG':'FTAGa'})
away.head()
# Out:
#           team  Pa  awinvalue  FTHGa  FTAGa
# 0      Arsenal  19        9.5     31     26
# 1  Aston Villa  19        7.5     25     23
# 2    Brentford  19        8.0     35     26
# 3     Brighton  19       11.0     21     23
# 4      Burnley  19        6.0     28     16

# %%
# Merge home and away together
df_merge = pd.merge(home, away, on = ['team'])
df_merge.head()
# Out:
#           team Div  Ph  hwinvalue  FTHGh  FTAGh  Pa  awinvalue  FTHGa  FTAGa
# 0      Arsenal  E0  19       14.0     35     17  19        9.5     31     26
# 1  Aston Villa  E0  19        8.5     29     29  19        7.5     25     23
# 2    Brentford  E0  19        8.5     22     21  19        8.0     35     26
# 3     Brighton  E0  19        8.5     19     23  19       11.0     21     23
# 4      Burnley  E0  19        8.0     18     25  19        6.0     28     16

# %%
# Sum the results to get the team overall performance
df_merge['W'] = df_merge['hwinvalue']+df_merge['awinvalue']
df_merge['G'] = df_merge['Ph']+df_merge['Pa']
df_merge['GF'] = df_merge['FTHGh']+df_merge['FTHGa']
df_merge['GA'] = df_merge['FTAGh']+df_merge['FTHGa']
df_merge.head()
# Out:
#           team Div  Ph  hwinvalue  FTHGh  FTAGh  Pa  awinvalue  FTHGa  FTAGa  \
# 0      Arsenal  E0  19       14.0     35     17  19        9.5     31     26
# 1  Aston Villa  E0  19        8.5     29     29  19        7.5     25     23
# 2    Brentford  E0  19        8.5     22     21  19        8.0     35     26
# 3     Brighton  E0  19        8.5     19     23  19       11.0     21     23
# 4      Burnley  E0  19        8.0     18     25  19        6.0     28     16
#
#       W   G  GF  GA
# 0  23.5  38  66  48
# 1  16.0  38  54  54
# 2  16.5  38  57  56
# 3  19.5  38  40  44
# 4  14.0  38  46  53

# %%
# Create winning percentage column and Pythagorean Expectation
df_merge['win_p'] = df_merge['W']/df_merge['G']
df_merge['pyth'] = df_merge['GF']**2/(df_merge['GF']**2 + df_merge['GA']**2)
df_merge
# Out:
#               team Div  Ph  hwinvalue  FTHGh  FTAGh  Pa  awinvalue  FTHGa  \
# 0          Arsenal  E0  19       14.0     35     17  19        9.5     31
# 1      Aston Villa  E0  19        8.5     29     29  19        7.5     25
# 2        Brentford  E0  19        8.5     22     21  19        8.0     35
# 3         Brighton  E0  19        8.5     19     23  19       11.0     21
# 4          Burnley  E0  19        8.0     18     25  19        6.0     28
# 5          Chelsea  E0  19       12.5     37     22  19       14.0     11
# 6   Crystal Palace  E0  19       11.0     27     17  19        7.5     29
# 7          Everton  E0  19       10.0     27     25  19        4.0     41
# 8            Leeds  E0  19        7.0     19     38  19        7.5     41
# 9        Leicester  E0  19       12.0     34     23  19        7.0     36
# 10       Liverpool  E0  19       17.0     49      9  19       15.0     17
# 11        Man City  E0  19       16.0     58     15  19       16.0     11
# 12      Man United  E0  19       12.5     32     22  19        8.5     35
# 13       Newcastle  E0  19       11.0     26     27  19        7.0     35
# 14         Norwich  E0  19        4.5     12     43  19        4.0     41
# 15     Southampton  E0  19        9.5     23     24  19        6.0     43
# 16       Tottenham  E0  19       13.5     38     19  19       11.0     21
# 17         Watford  E0  19        3.0     17     46  19        5.5     31
# 18        West Ham  E0  19       11.5     33     26  19        8.5     25
# 19          Wolves  E0  19        8.5     20     25  19        9.5     18
#
#     FTAGa     W   G  GF  GA     win_p      pyth
# 0      26  23.5  38  66  48  0.618421  0.654054
# 1      23  16.0  38  54  54  0.421053  0.500000
# 2      26  16.5  38  57  56  0.434211  0.508849
# 3      23  19.5  38  40  44  0.513158  0.452489
# 4      16  14.0  38  46  53  0.368421  0.429645
# 5      39  26.5  38  48  33  0.697368  0.679045
# 6      23  18.5  38  56  46  0.486842  0.597106
# 7      16  14.0  38  68  66  0.368421  0.514922
# 8      23  14.5  38  60  79  0.381579  0.365816
# 9      28  19.0  38  70  59  0.500000  0.584656
# 10     45  32.0  38  66  26  0.842105  0.865660
# 11     41  32.0  38  69  26  0.842105  0.875667
# 12     25  21.0  38  67  57  0.552632  0.580124
# 13     18  18.0  38  61  62  0.473684  0.491870
# 14     11   8.5  38  53  84  0.223684  0.284744
# 15     20  15.5  38  66  67  0.407895  0.492482
# 16     31  24.5  38  59  40  0.644737  0.685101
# 17     17   8.5  38  48  77  0.223684  0.279849
# 18     27  20.0  38  58  51  0.526316  0.563956
# 19     18  18.0  38  38  43  0.473684  0.438506

# %%
sns.relplot(x='pyth', y='win_p', data=df_merge)

# Add annotations for each point with an offset
for i in range(df_merge.shape[0]):
    plt.annotate(df_merge['team'][i], 
                 (df_merge['pyth'][i], df_merge['win_p'][i]), 
                 textcoords="offset points", 
                 xytext=(5,-6),  # Adjust these values to reduce overlap
                 ha='center', fontsize=9)

# Show the plot
plt.show()

# %%
reg1 = sm.ols(formula = 'win_p ~ pyth', data= df_merge)
model = reg1.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  win_p   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     185.1
# Date:                Fri, 19 Jul 2024   Prob (F-statistic):           6.51e-11
# Time:                        09:04:37   Log-Likelihood:                 32.095
# No. Observations:                  20   AIC:                            -60.19
# Df Residuals:                      18   BIC:                            -58.20
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0455      0.042     -1.090      0.290      -0.133       0.042
# pyth           1.0060      0.074     13.606      0.000       0.851       1.161
# ==============================================================================
# Omnibus:                        0.354   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.838   Jarque-Bera (JB):                0.074
# Skew:                           0.143   Prob(JB):                        0.964
# Kurtosis:                       2.914   Cond. No.                         8.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Analysis
# - Top teams are Liverpool and Man City, but Man City has a bit higher Pythagorean Expectation score
# - Chealsea, Tottenham, Arsenal are in the next section
# - Regression analysis indicates that the **R-sq = 0.911**, which is a very strong fit using Pythagorean Expectation to predict Winning rate
# - The coefficient of 1.0060 for the pyth variable means that for every one-unit increase in the pyth value, the win_p (winning percentage) is expected to increase by approximately 1.0060 units.
# - Linear regression equation:**win_p = -0.0455 + 1.0060 x pyth**

# %% [markdown]
# # Man City
# - Since I'm a fan of Man City, I'm going to focus on their team performance

# %%
# Focus on Man City
mancity = df[(df['HomeTeam'] == 'Man City') | (df['AwayTeam'] == 'Man City')]
mancity.head()
# Out:
#    Div        Date   Time   HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 9   E0  15/08/2021  16:30  Tottenham     Man City     1     0   H     0     0
# 14  E0  21/08/2021  15:00   Man City      Norwich     5     0   H     2     0
# 20  E0  28/08/2021  12:30   Man City      Arsenal     5     0   H     3     0
# 33  E0  11/09/2021  15:00  Leicester     Man City     0     1   A     0     0
# 44  E0  18/09/2021  15:00   Man City  Southampton     0     0   D     0     0
#
#     ... B365CAHA PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  hwinvalue  \
# 9   ...     2.09  1.87   2.06     1.94     2.15     1.84     2.05        1.0
# 14  ...     1.80  2.07   1.85     2.11     1.97     2.04     1.84        1.0
# 20  ...     1.77  2.14   1.79     2.15     2.05     2.05     1.83        1.0
# 33  ...     2.05  1.81   2.12     1.90     2.22     1.79     2.10        0.0
# 44  ...     2.06  1.87   2.04     1.91     2.18     1.84     2.05        0.5
#
#     awinvalue  count
# 9         0.0      1
# 14        0.0      1
# 20        0.0      1
# 33        1.0      1
# 44        0.5      1
#
# [5 rows x 109 columns]

# %%
# Separate the Man City Home and Away games
mancity_home = mancity[mancity['HomeTeam']=='Man City']
mancity_away = mancity[mancity['AwayTeam']=='Man City']

# %%
# Full time goal in home and away games 
print('Home', mancity_home['FTHG'].describe())
print()
print('Away', mancity_away['FTAG'].describe())
print()
print('FTG Mean', (mancity_home['FTHG'].mean()+mancity_away['FTAG'].mean())/2)
# Out:
# Home count    19.000000
# mean      3.052632
# std       2.013115
# min       0.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max       7.000000
# Name: FTHG, dtype: float64
#
# Away count    19.000000
# mean      2.157895
# std       1.462994
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.500000
# max       5.000000
# Name: FTAG, dtype: float64
#
# FTG Mean 2.605263157894737

# %%
# Shots
print('Home', mancity_home['HS'].describe())
print()
print('Away', mancity_away['AS'].describe())
print()
print('Shots Mean', (mancity_home['HS'].mean()+mancity_away['AS'].mean())/2)
# Out:
# Home count    19.000000
# mean     19.000000
# std       5.131601
# min      11.000000
# 25%      15.500000
# 50%      18.000000
# 75%      22.500000
# max      31.000000
# Name: HS, dtype: float64
#
# Away count    19.000000
# mean     18.631579
# std       4.968909
# min      12.000000
# 25%      15.500000
# 50%      18.000000
# 75%      21.000000
# max      31.000000
# Name: AS, dtype: float64
#
# Shots Mean 18.815789473684212

# %%
# Shots on Target
print('Home', mancity_home['HST'].describe())
print()
print('Away', mancity_away['AST'].describe())
print()
print('Shots on Target Mean', (mancity_home['HST'].mean()+mancity_away['AST'].mean())/2)
# Out:
# Home count    19.000000
# mean      7.000000
# std       3.231787
# min       1.000000
# 25%       5.000000
# 50%       7.000000
# 75%       9.000000
# max      15.000000
# Name: HST, dtype: float64
#
# Away count    19.000000
# mean      6.368421
# std       3.183473
# min       2.000000
# 25%       4.000000
# 50%       6.000000
# 75%       8.000000
# max      14.000000
# Name: AST, dtype: float64
#
# Shots on Target Mean 6.684210526315789

# %%
print('Shots & Score ratio', 2.61/18.82)
print('Shots & Shots on Target ratio', 6.68/18.12)
print('Shots on Target & Score ratio', 2.61/6.68)
# Out:
# Shots & Score ratio 0.13868225292242295
# Shots & Shots on Target ratio 0.368653421633554
# Shots on Target & Score ratio 0.3907185628742515

# %%
# Goals scored and conceded in home matches
home_goals_scored = mancity[mancity['HomeTeam'] == 'Man City']['FTHG'].sum()
home_goals_conceded = mancity[mancity['HomeTeam'] == 'Man City']['FTAG'].sum()

# Goals scored and conceded in away matches
away_goals_scored = mancity[mancity['AwayTeam'] == 'Man City']['FTAG'].sum()
away_goals_conceded = mancity[mancity['AwayTeam'] == 'Man City']['FTHG'].sum()

print(f"Home Goals Scored: {home_goals_scored}, Home Goals Conceded: {home_goals_conceded}")
print(f"Away Goals Scored: {away_goals_scored}, Away Goals Conceded: {away_goals_conceded}")

# Visualize
data = {
    'Goals Scored': [home_goals_scored, away_goals_scored],
    'Goals Conceded': [home_goals_conceded, away_goals_conceded]
}

index = ['Home', 'Away']
df_goals = pd.DataFrame(data, index=index)

df_goals.plot(kind='bar')
plt.title('Goals Scored and Conceded by Manchester City')
plt.ylabel('Goals')
plt.xlabel('Home/Away')
plt.show()
# Out:
# Home Goals Scored: 58, Home Goals Conceded: 15
# Away Goals Scored: 41, Away Goals Conceded: 11

# %%
# Foul committed in Home and Away games
print('Home', mancity_home['HF'].describe())
print()
print('Away', mancity_away['AF'].describe())
# Out:
# Home count    19.000000
# mean      8.368421
# std       2.947891
# min       5.000000
# 25%       5.000000
# 50%       9.000000
# 75%      11.000000
# max      13.000000
# Name: HF, dtype: float64
#
# Away count    19.000000
# mean      8.473684
# std       3.115703
# min       3.000000
# 25%       6.000000
# 50%       8.000000
# 75%      11.000000
# max      14.000000
# Name: AF, dtype: float64

# %% [markdown]
# # Man City vs Aston Villa (May/22/2022)
# - Now we pick a game to look deeper

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
# Scrape a single game shots. We will allow users to enter a base url
# 16754
base_url = 'https://understat.com/match/'
match = str(input('Please enter the match id: '))
url = base_url+match
# Out:
# Please enter the match id: 16754

# %%
# Use requests to get the webpage and BeautifulSoup to parse the page
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
scripts = soup.find_all('script')

# %% [markdown]
# ## Shots

# %%
# Get only the shotsData
strings = scripts[1].string
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22477932\\x22,\\x22minute\\x22\\x3A\\x222\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.955999984741211\\x22,\\x22Y\\x22\\x3A\\x220.605999984741211\\x22,\\x22xG\\x22\\x3A\\x220.06356179714202881\\x22,\\x22player\\x22\\x3A\\x22Fernandinho\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22614\\x22,\\x22situation\\x22\\x3A\\x22SetPiece\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22Head\\x22,\\x22match_id\\x22\\x3A\\x2216754\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D05\\x2D22\\x2015\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Kevin\\x20De\\x20Bruyne\\x22,\\x22lastAction\\x22\\x3A\\x22Cross\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22477933\\x22,\\x22minute\\x22\\x3A\\x224\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.855\\x22,\\x22Y\\x22\\x3A\\x220.649000015258789\\x22,\\x22xG\\x22\\x3A\\x220.06113560125231743\\x22,\\x22player\\x22\\x3A\\x22Jo\\x5Cu00e3o\\x20Cancelo\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222379\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216754\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D05\\x2D22\\x2015\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Phil\\x20Foden\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22477934\\x22,\\x22minute\\x22\\x3A\\x2223\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.8569999694824219\\x22,\\x22Y\\x22\\x3A\\x220.43099998474121093\\x22,\\x22xG\\x22\\x3A\\x220.0956450030207634\\x22,\\x22player\\x22\\x3A\\x22Phil\\x20Foden\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x226055\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216754\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D05\\x2D22\\x2015\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Gabriel\\x20Jesus\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22477935\\x22,\\x22minute\\x22\\x3A\\x2227\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.8919999694824219\\x22,\\x22Y\\x22\\x3A\\x220.74\\x22,\\x22xG\\x22\\x3A\\x220.03272930160164833\\x22,\\x22player\\x22\\x3A\\x22Jo\\x5Cu00e3o\\x20Cancelo\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222379\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2216754\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Aston\\x20Villa\\x22,\\x22h_goals\\x22\\x3A\\x223\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D05\\x2D22\\x2015\\x3A00\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22John\\x20Stones\\x22,\\x22lastAction\\x22\\x3A\\x22Chipped\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22477936\\x22,\\x22minute\\x22\\x3A\\x2230\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.845999984741211\\x22,\\x22Y\\x22\\x3A\\x220.6140000152587891\\x22,\\x22xG\\x22\\x3A\\x220.06224840134382248\\x22,\\x22player\\x22\\x3A\\x22Gabriel\\x20Jesus\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225543\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot ...

# %%
# strip unnecessary symbols and get only JSON data 
ind_start = strings.index("('")+2 
ind_end = strings.index("')") 
json_data = strings[ind_start:ind_end] 
json_data = json_data.encode('utf8').decode('unicode_escape')

#convert string to json format
shots = json.loads(json_data)
shots
# Out:
# {'h': [{'id': '477932',
#    'minute': '2',
#    'result': 'MissedShots',
#    'X': '0.955999984741211',
#    'Y': '0.605999984741211',
#    'xG': '0.06356179714202881',
#    'player': 'Fernandinho',
#    'h_a': 'h',
#    'player_id': '614',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Cross'},
#   {'id': '477933',
#    'minute': '4',
#    'result': 'BlockedShot',
#    'X': '0.855',
#    'Y': '0.649000015258789',
#    'xG': '0.06113560125231743',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'Pass'},
#   {'id': '477934',
#    'minute': '23',
#    'result': 'BlockedShot',
#    'X': '0.8569999694824219',
#    'Y': '0.43099998474121093',
#    'xG': '0.0956450030207634',
#    'player': 'Phil Foden',
#    'h_a': 'h',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'Pass'},
#   {'id': '477935',
#    'minute': '27',
#    'result': 'BlockedShot',
#    'X': '0.8919999694824219',
#    'Y': '0.74',
#    'xG': '0.03272930160164833',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'John Stones',
#    'lastAction': 'Chipped'},
#   {'id': '477936',
#    'minute': '30',
#    'result': 'MissedShots',
#    'X': '0.845999984741211',
#    'Y': '0.6140000152587891',
#    'xG': '0.06224840134382248',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'BallRecovery'},
#   {'id': '477940',
#    'minute': '43',
#    'result': 'BlockedShot',
#    'X': '0.9680000305175781',
#    'Y': '0.34700000762939454',
#    'xG': '0.05484690144658089',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'None'},
#   {'id': '477941',
#    'minute': '44',
#    'result': 'BlockedShot',
#    'X': '0.75',
#    'Y': '0.7069999694824218',
#    'xG': '0.01756650023162365',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Pass'},
#   {'id': '477942',
#    'minute': '46',
#    'result': 'BlockedShot',
#    'X': '0.7859999847412109',
#    'Y': '0.610999984741211',
#    'xG': '0.025742100551724434',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Pass'},
#   {'id': '477943',
#    'minute': '47',
#    'result': 'SavedShot',
#    'X': '0.9180000305175782',
#    'Y': '0.5640000152587891',
#    'xG': '0.06785249710083008',
#    'player': 'Aymeric Laporte',
#    'h_a': 'h',
#    'player_id': '2498',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Riyad Mahrez',
#    'lastAction': 'Cross'},
#   {'id': '477944',
#    'minute': '47',
#    'result': 'MissedShots',
#    'X': '0.8980000305175782',
#    'Y': '0.425',
#    'xG': '0.05072680115699768',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'},
#   {'id': '477945',
#    'minute': '49',
#    'result': 'BlockedShot',
#    'X': '0.9319999694824219',
#    'Y': '0.5120000076293946',
#    'xG': '0.13576699793338776',
#    'player': 'Riyad Mahrez',
#    'h_a': 'h',
#    'player_id': '750',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Oleksandr Zinchenko',
#    'lastAction': 'Pass'},
#   {'id': '477946',
#    'minute': '49',
#    'result': 'MissedShots',
#    'X': '0.9640000152587891',
#    'Y': '0.5320000076293945',
#    'xG': '0.586322009563446',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Cross'},
#   {'id': '477947',
#    'minute': '50',
#    'result': 'MissedShots',
#    'X': '0.769000015258789',
#    'Y': '0.34',
#    'xG': '0.020437700673937798',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Riyad Mahrez',
#    'lastAction': 'Pass'},
#   {'id': '477948',
#    'minute': '53',
#    'result': 'BlockedShot',
#    'X': '0.9230000305175782',
#    'Y': '0.48400001525878905',
#    'xG': '0.05040640011429787',
#    'player': 'John Stones',
#    'h_a': 'h',
#    'player_id': '586',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Aerial'},
#   {'id': '477949',
#    'minute': '66',
#    'result': 'BlockedShot',
#    'X': '0.919000015258789',
#    'Y': '0.6430000305175781',
#    'xG': '0.055538300424814224',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Phil Foden',
#    'lastAction': 'Cross'},
#   {'id': '477950',
#    'minute': '67',
#    'result': 'MissedShots',
#    'X': '0.7919999694824219',
#    'Y': '0.735',
#    'xG': '0.05326959863305092',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '477952',
#    'minute': '70',
#    'result': 'MissedShots',
#    'X': '0.845999984741211',
#    'Y': '0.5579999923706055',
#    'xG': '0.09440559893846512',
#    'player': 'Phil Foden',
#    'h_a': 'h',
#    'player_id': '6055',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Rodri',
#    'lastAction': 'TakeOn'},
#   {'id': '477953',
#    'minute': '72',
#    'result': 'MissedShots',
#    'X': '0.8580000305175781',
#    'Y': '0.5220000076293946',
#    'xG': '0.13904300332069397',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'Pass'},
#   {'id': '477954',
#    'minute': '73',
#    'result': 'MissedShots',
#    'X': '0.9280000305175782',
#    'Y': '0.5420000076293945',
#    'xG': '0.06157840043306351',
#    'player': 'Ilkay Gündogan',
#    'h_a': 'h',
#    'player_id': '314',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Aerial'},
#   {'id': '477955',
#    'minute': '75',
#    'result': 'Goal',
#    'X': '0.9669999694824218',
#    'Y': '0.555',
#    'xG': '0.5095549821853638',
#    'player': 'Ilkay Gündogan',
#    'h_a': 'h',
#    'player_id': '314',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'Cross'},
#   {'id': '477956',
#    'minute': '76',
#    'result': 'SavedShot',
#    'X': '0.9219999694824219',
#    'Y': '0.545',
#    'xG': '0.08914720267057419',
#    'player': 'John Stones',
#    'h_a': 'h',
#    'player_id': '586',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Cross'},
#   {'id': '477957',
#    'minute': '77',
#    'result': 'Goal',
#    'X': '0.8169999694824219',
#    'Y': '0.5820000076293945',
#    'xG': '0.04535669833421707',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Oleksandr Zinchenko',
#    'lastAction': 'Pass'},
#   {'id': '477958',
#    'minute': '79',
#    'result': 'MissedShots',
#    'X': '0.8230000305175781',
#    'Y': '0.34900001525878904',
#    'xG': '0.042314499616622925',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Chipped'},
#   {'id': '477959',
#    'minute': '80',
#    'result': 'MissedShots',
#    'X': '0.9030000305175782',
#    'Y': '0.27399999618530274',
#    'xG': '0.04056769981980324',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '477960',
#    'minute': '80',
#    'result': 'Goal',
#    'X': '0.980999984741211',
#    'Y': '0.5359999847412109',
#    'xG': '0.9017159938812256',
#    'player': 'Ilkay Gündogan',
#    'h_a': 'h',
#    'player_id': '314',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Rebound'}],
#  'a': [{'id': '477937',
#    'minute': '36',
#    'result': 'Goal',
#    'X': '0.925',
#    'Y': '0.45299999237060545',
#    'xG': '0.06013130024075508',
#    'player': 'Matthew Cash',
#    'h_a': 'a',
#    'player_id': '8864',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'Head',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Lucas Digne',
#    'lastAction': 'Aerial'},
#   {'id': '477938',
#    'minute': '40',
#    'result': 'BlockedShot',
#    'X': '0.8680000305175781',
#    'Y': '0.36400001525878906',
#    'xG': '0.08686979860067368',
#    'player': 'Ollie Watkins',
#    'h_a': 'a',
#    'player_id': '8865',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Philippe Coutinho',
#    'lastAction': 'Pass'},
#   {'id': '477939',
#    'minute': '41',
#    'result': 'MissedShots',
#    'X': '0.7319999694824219',
#    'Y': '0.4159999847412109',
#    'xG': '0.02091990038752556',
#    'player': 'Philippe Coutinho',
#    'h_a': 'a',
#    'player_id': '488',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Ollie Watkins',
#    'lastAction': 'None'},
#   {'id': '477951',
#    'minute': '68',
#    'result': 'Goal',
#    'X': '0.855999984741211',
#    'Y': '0.6229999923706054',
#    'xG': '0.07991970330476761',
#    'player': 'Philippe Coutinho',
#    'h_a': 'a',
#    'player_id': '488',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16754',
#    'h_team': 'Manchester City',
#    'a_team': 'Aston Villa',
#    'h_goals': '3',
#    'a_goals': '2',
#    'date': '2022-05-22 15:00:00',
#    'player_assisted': 'Ollie Watkins',
#    'lastAction': 'HeadPass'}]}

# %%
x = []
y = []
xG = []
result = []
player = []
team = []
data_away = shots['a']
data_home = shots['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_away[index][key])

# %%
col_names = ['x','y','xG','result','player','team']
df_shots = pd.DataFrame([x,y,xG,result,player,team],index=col_names)
df_shots = df_shots.T
df_shots
# Out:
#                      x                    y                    xG  \
# 0    0.955999984741211    0.605999984741211   0.06356179714202881
# 1                0.855    0.649000015258789   0.06113560125231743
# 2   0.8569999694824219  0.43099998474121093    0.0956450030207634
# 3   0.8919999694824219                 0.74   0.03272930160164833
# 4    0.845999984741211   0.6140000152587891   0.06224840134382248
# 5   0.9680000305175781  0.34700000762939454   0.05484690144658089
# 6                 0.75   0.7069999694824218   0.01756650023162365
# 7   0.7859999847412109    0.610999984741211  0.025742100551724434
# 8   0.9180000305175782   0.5640000152587891   0.06785249710083008
# 9   0.8980000305175782                0.425   0.05072680115699768
# 10  0.9319999694824219   0.5120000076293946   0.13576699793338776
# 11  0.9640000152587891   0.5320000076293945     0.586322009563446
# 12   0.769000015258789                 0.34  0.020437700673937798
# 13  0.9230000305175782  0.48400001525878905   0.05040640011429787
# 14   0.919000015258789   0.6430000305175781  0.055538300424814224
# 15  0.7919999694824219                0.735   0.05326959863305092
# 16   0.845999984741211   0.5579999923706055   0.09440559893846512
# 17  0.8580000305175781   0.5220000076293946   0.13904300332069397
# 18  0.9280000305175782   0.5420000076293945   0.06157840043306351
# 19  0.9669999694824218                0.555    0.5095549821853638
# 20  0.9219999694824219                0.545   0.08914720267057419
# 21  0.8169999694824219   0.5820000076293945   0.04535669833421707
# 22  0.8230000305175781  0.34900001525878904  0.042314499616622925
# 23  0.9030000305175782  0.27399999618530274   0.04056769981980324
# 24   0.980999984741211   0.5359999847412109    0.9017159938812256
# 25               0.925  0.45299999237060545   0.06013130024075508
# 26  0.8680000305175781  0.36400001525878906   0.08686979860067368
# 27  0.7319999694824219   0.4159999847412109   0.02091990038752556
# 28   0.855999984741211   0.6229999923706054   0.07991970330476761
#
#          result             player             team
# 0   MissedShots        Fernandinho  Manchester City
# 1   BlockedShot       João Cancelo  Manchester City
# 2   BlockedShot         Phil Foden  Manchester City
# 3   BlockedShot       João Cancelo  Manchester City
# 4   MissedShots      Gabriel Jesus  Manchester City
# 5   BlockedShot    Kevin De Bruyne  Manchester City
# 6   BlockedShot       João Cancelo  Manchester City
# 7   BlockedShot       João Cancelo  Manchester City
# 8     SavedShot    Aymeric Laporte  Manchester City
# 9   MissedShots    Kevin De Bruyne  Manchester City
# 10  BlockedShot       Riyad Mahrez  Manchester City
# 11  MissedShots      Gabriel Jesus  Manchester City
# 12  MissedShots              Rodri  Manchester City
# 13  BlockedShot        John Stones  Manchester City
# 14  BlockedShot      Gabriel Jesus  Manchester City
# 15  MissedShots    Kevin De Bruyne  Manchester City
# 16  MissedShots         Phil Foden  Manchester City
# 17  MissedShots    Kevin De Bruyne  Manchester City
# 18  MissedShots     Ilkay Gündogan  Manchester City
# 19         Goal     Ilkay Gündogan  Manchester City
# 20    SavedShot        John Stones  Manchester City
# 21         Goal              Rodri  Manchester City
# 22  MissedShots              Rodri  Manchester City
# 23  MissedShots    Kevin De Bruyne  Manchester City
# 24         Goal     Ilkay Gündogan  Manchester City
# 25         Goal       Matthew Cash      Aston Villa
# 26  BlockedShot      Ollie Watkins      Aston Villa
# 27  MissedShots  Philippe Coutinho      Aston Villa
# 28         Goal  Philippe Coutinho      Aston Villa

# %%
# Plot the shot map

# Ensure the result column is treated as a categorical variable
df_shots['result'] = df_shots['result'].astype('category')

# Draw a pitch
pitch = Pitch(line_color='black', pitch_color='grass', pitch_type='statsbomb')
fig, ax = pitch.draw(figsize=(10, 7))

# Define color mapping for different shot results
color_mapping = {
    'Goal': 'blue',
    'MissedShots': 'red',
    'BlockedShot': 'orange',
    'SavedShot': 'green'
}

# Scale x and y coordinates to fit the pitch dimensions (120x80)
df_shots['x'] = df_shots['x'].astype(float) * 120
df_shots['y'] = df_shots['y'].astype(float) * 80

# Mirror Aston Villa's shots to the opposite side of the pitch
df_shots.loc[df_shots['team'] == 'Aston Villa', 'x'] = 120 - df_shots.loc[df_shots['team'] == 'Aston Villa', 'x']

# Plot shots for both teams
for team in ['Manchester City', 'Aston Villa']:
    team_shots = df_shots[df_shots['team'] == team]
    for i, shot in team_shots.iterrows():
        x = shot['x']
        y = shot['y']
        result = shot['result']
        color = color_mapping[result]
        if result == 'Goal':
            shot_circle = plt.Circle((x, y), 2.5, color=color, edgecolor='black' if team == 'Aston Villa' else 'none')  # Larger size for goals
            plt.text(x, y, shot['player'], fontsize=10, color='white' if team == 'Aston Villa' else 'black')
        else:
            shot_circle = plt.Circle((x, y), 1, color=color, edgecolor='black' if team == 'Aston Villa' else 'none')
        ax.add_patch(shot_circle)

# Set the limits for the x and y axes
ax.set_xlim(0, 120)
ax.set_ylim(0, 80)

# Create legend
from matplotlib.lines import Line2D

legend_elements = [
    Line2D([0], [0], marker='o', color='w', label='Goal', markerfacecolor='blue', markersize=10),
    Line2D([0], [0], marker='o', color='w', label='Missed Shots', markerfacecolor='red', markersize=6),
    Line2D([0], [0], marker='o', color='w', label='Blocked Shots', markerfacecolor='orange', markersize=6),
    Line2D([0], [0], marker='o', color='w', label='Saved Shots', markerfacecolor='green', markersize=6)
]

ax.legend(handles=legend_elements, loc='upper right')

plt.title('Shots Map: Manchester City vs Aston Villa')
plt.show()

# %% [markdown]
# ## xG (Expected Goal)
# - A way to measure the quality of the shot
# - By using angle of the shot, type of assist, the probability of goal
# - 0-1, 0.5 means 50% chance to make it a goal
# - The higher the xG, the more likely it will be scored

# %%
import matplotlib as mpl

# %%
# Add shot minute column to the data frame
x = []
y = []
xG = []
result = []
player = []
team = []
minute = []
data_away = shots['a']
data_home = shots['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'minute':
            minute.append(data_home[index][key])
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'minute':
            minute.append(data_home[index][key])
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_away[index][key])

col_names = ['minute','x','y','xG','result','player','team']
df_shots = pd.DataFrame([minute,x,y,xG,result,player,team],index=col_names)
df_shots = df_shots.T
df_shots
# Out:
#    minute                   x                    y                    xG  \
# 0       2   0.955999984741211    0.605999984741211   0.06356179714202881
# 1       4               0.855    0.649000015258789   0.06113560125231743
# 2      23  0.8569999694824219  0.43099998474121093    0.0956450030207634
# 3      27  0.8919999694824219                 0.74   0.03272930160164833
# 4      30   0.845999984741211   0.6140000152587891   0.06224840134382248
# 5      43  0.9680000305175781  0.34700000762939454   0.05484690144658089
# 6      44                0.75   0.7069999694824218   0.01756650023162365
# 7      46  0.7859999847412109    0.610999984741211  0.025742100551724434
# 8      47  0.9180000305175782   0.5640000152587891   0.06785249710083008
# 9      47  0.8980000305175782                0.425   0.05072680115699768
# 10     49  0.9319999694824219   0.5120000076293946   0.13576699793338776
# 11     49  0.9640000152587891   0.5320000076293945     0.586322009563446
# 12     50   0.769000015258789                 0.34  0.020437700673937798
# 13     53  0.9230000305175782  0.48400001525878905   0.05040640011429787
# 14     66   0.919000015258789   0.6430000305175781  0.055538300424814224
# 15     67  0.7919999694824219                0.735   0.05326959863305092
# 16     70   0.845999984741211   0.5579999923706055   0.09440559893846512
# 17     72  0.8580000305175781   0.5220000076293946   0.13904300332069397
# 18     73  0.9280000305175782   0.5420000076293945   0.06157840043306351
# 19     75  0.9669999694824218                0.555    0.5095549821853638
# 20     76  0.9219999694824219                0.545   0.08914720267057419
# 21     77  0.8169999694824219   0.5820000076293945   0.04535669833421707
# 22     79  0.8230000305175781  0.34900001525878904  0.042314499616622925
# 23     80  0.9030000305175782  0.27399999618530274   0.04056769981980324
# 24     80   0.980999984741211   0.5359999847412109    0.9017159938812256
# 25      2               0.925  0.45299999237060545   0.06013130024075508
# 26      4  0.8680000305175781  0.36400001525878906   0.08686979860067368
# 27     23  0.7319999694824219   0.4159999847412109   0.02091990038752556
# 28     27   0.855999984741211   0.6229999923706054   0.07991970330476761
#
#          result             player             team
# 0   MissedShots        Fernandinho  Manchester City
# 1   BlockedShot       João Cancelo  Manchester City
# 2   BlockedShot         Phil Foden  Manchester City
# 3   BlockedShot       João Cancelo  Manchester City
# 4   MissedShots      Gabriel Jesus  Manchester City
# 5   BlockedShot    Kevin De Bruyne  Manchester City
# 6   BlockedShot       João Cancelo  Manchester City
# 7   BlockedShot       João Cancelo  Manchester City
# 8     SavedShot    Aymeric Laporte  Manchester City
# 9   MissedShots    Kevin De Bruyne  Manchester City
# 10  BlockedShot       Riyad Mahrez  Manchester City
# 11  MissedShots      Gabriel Jesus  Manchester City
# 12  MissedShots              Rodri  Manchester City
# 13  BlockedShot        John Stones  Manchester City
# 14  BlockedShot      Gabriel Jesus  Manchester City
# 15  MissedShots    Kevin De Bruyne  Manchester City
# 16  MissedShots         Phil Foden  Manchester City
# 17  MissedShots    Kevin De Bruyne  Manchester City
# 18  MissedShots     Ilkay Gündogan  Manchester City
# 19         Goal     Ilkay Gündogan  Manchester City
# 20    SavedShot        John Stones  Manchester City
# 21         Goal              Rodri  Manchester City
# 22  MissedShots              Rodri  Manchester City
# 23  MissedShots    Kevin De Bruyne  Manchester City
# 24         Goal     Ilkay Gündogan  Manchester City
# 25         Goal       Matthew Cash      Aston Villa
# 26  BlockedShot      Ollie Watkins      Aston Villa
# 27  MissedShots  Philippe Coutinho      Aston Villa
# 28         Goal  Philippe Coutinho      Aston Villa

# %%
a_xg = [0]
h_xg = [0]
a_min = [0]
h_min = [0]

# find home and away team

hteam= df_shots['team'].iloc[0]
ateam = df_shots['team'].iloc[-1]

for x in range(len(df_shots['xG'])):
    if df_shots['team'][x]==ateam:
        a_xg.append(df_shots['xG'][x])
        a_min.append(df_shots['minute'][x])
    if df_shots['team'][x]==hteam:
        h_xg.append(df_shots['xG'][x])
        h_min.append(df_shots['minute'][x])

# %%
# This is each shot
print(a_xg)
print(h_xg)
# Out:
# [0, '0.06013130024075508', '0.08686979860067368', '0.02091990038752556', '0.07991970330476761']
# [0, '0.06356179714202881', '0.06113560125231743', '0.0956450030207634', '0.03272930160164833', '0.06224840134382248', '0.05484690144658089', '0.01756650023162365', '0.025742100551724434', '0.06785249710083008', '0.05072680115699768', '0.13576699793338776', '0.586322009563446', '0.020437700673937798', '0.05040640011429787', '0.055538300424814224', '0.05326959863305092', '0.09440559893846512', '0.13904300332069397', '0.06157840043306351', '0.5095549821853638', '0.08914720267057419', '0.04535669833421707', '0.042314499616622925', '0.04056769981980324', '0.9017159938812256']

# %%
# Make each shot cumulative
def nums_cumulative_sum(nums_list):
    return [sum(nums_list[:i+1]) for i in range(len(nums_list))]

# Make sure the value in a_xg and h_xg are float
def to_float(nums_list):
    result = []
    for num in nums_list:
        try:
            result.append(float(num))
        except ValueError:
            continue
    return result

a_xg = to_float(a_xg)
h_xg = to_float(h_xg)

a_cumulative = nums_cumulative_sum(a_xg)
h_cumulative = nums_cumulative_sum(h_xg)

# %%
# Now it's the cumulative xG for away team for plotting
print(a_cumulative)
print(h_cumulative)
# Out:
# [0.0, 0.06013130024075508, 0.14700109884142876, 0.16792099922895432, 0.24784070253372192]
# [0.0, 0.06356179714202881, 0.12469739839434624, 0.22034240141510963, 0.25307170301675797, 0.31532010436058044, 0.37016700580716133, 0.387733506038785, 0.4134756065905094, 0.4813281036913395, 0.5320549048483372, 0.6678219027817249, 1.254143912345171, 1.2745816130191088, 1.3249880131334066, 1.3805263135582209, 1.4337959121912718, 1.528201511129737, 1.6672445144504309, 1.7288229148834944, 2.238377897068858, 2.3275250997394323, 2.3728817980736494, 2.4151962976902723, 2.4557639975100756, 3.357479991391301]

# %%
a_total = round(a_cumulative[-1],2)
h_total = round(h_cumulative[-1],2)

# %%
# Plot the Cumulative xGs
fig, ax = plt.subplots(figsize=(10, 5))
fig.set_facecolor('gray')
ax.patch.set_facecolor('gray')

# Set x-ticks and labels
plt.xticks([0, 15, 30, 45, 60, 75, 90])
plt.xlabel('Minute')
plt.ylabel('xG')

# Plot the cumulative xG with transparency
ax.step(x=a_min, y=a_cumulative, where='post', color='red', alpha=1, linewidth=2, label='Aston Villa')
ax.step(x=h_min, y=h_cumulative, where='post', color='lightblue', alpha=0.7, linewidth=3, label='Man City')

# Add legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## Player performance

# %%
# Add shotType, player_assisted, lastAction columns to the data frame
x = []
y = []
xG = []
result = []
player = []
shotType = []
player_assisted = []
lastAction = []
team = []
minute = []
data_away = shots['a']
data_home = shots['h']

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == 'minute':
            minute.append(data_home[index][key])
        if key == 'X':
            x.append(data_home[index][key])
        if key == 'Y':
            y.append(data_home[index][key])
        if key == 'h_team':
            team.append(data_home[index][key])
        if key == 'xG':
            xG.append(data_home[index][key])
        if key == 'result':
            result.append(data_home[index][key])
        if key == 'player':
            player.append(data_home[index][key])
        if key == 'shotType':
            shotType.append(data_home[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_home[index][key])
        if key == 'lastAction':
            lastAction.append(data_home[index][key])

for index in range(len(data_away)):
    for key in data_away[index]:
        if key == 'minute':
            minute.append(data_home[index][key])
        if key == 'X':
            x.append(data_away[index][key])
        if key == 'Y':
            y.append(data_away[index][key])
        if key == 'a_team':
            team.append(data_away[index][key])
        if key == 'xG':
            xG.append(data_away[index][key])
        if key == 'result':
            result.append(data_away[index][key])
        if key == 'player':
            player.append(data_away[index][key])
        if key == 'shotType':
            shotType.append(data_away[index][key])
        if key == 'player_assisted':
            player_assisted.append(data_away[index][key])
        if key == 'lastAction':
            lastAction.append(data_away[index][key])

col_names = ['minute','x','y','xG','result','player','shotType','player_assisted','lastAction','team']
df_shots = pd.DataFrame([minute,x,y,xG,result,player,shotType, player_assisted, lastAction, team],index=col_names)
df_shots = df_shots.T
df_shots.head()
# Out:
#   minute                   x                    y                   xG  \
# 0      2   0.955999984741211    0.605999984741211  0.06356179714202881
# 1      4               0.855    0.649000015258789  0.06113560125231743
# 2     23  0.8569999694824219  0.43099998474121093   0.0956450030207634
# 3     27  0.8919999694824219                 0.74  0.03272930160164833
# 4     30   0.845999984741211   0.6140000152587891  0.06224840134382248
#
#         result         player   shotType  player_assisted    lastAction  \
# 0  MissedShots    Fernandinho       Head  Kevin De Bruyne         Cross
# 1  BlockedShot   João Cancelo  RightFoot       Phil Foden          Pass
# 2  BlockedShot     Phil Foden  RightFoot    Gabriel Jesus          Pass
# 3  BlockedShot   João Cancelo   LeftFoot      John Stones       Chipped
# 4  MissedShots  Gabriel Jesus  RightFoot       Phil Foden  BallRecovery
#
#               team
# 0  Manchester City
# 1  Manchester City
# 2  Manchester City
# 3  Manchester City
# 4  Manchester City

# %% [markdown]
# ### Shot number and Avg xG score

# %%
# Ensure xG column is numeric
df_shots['xG'] = pd.to_numeric(df_shots['xG'], errors='coerce')

# Drop rows where xG is NaN (if any)
df_shots = df_shots.dropna(subset=['xG'])

# Total shots and average xG per player
player_shot_stats = df_shots.groupby('player').agg(total_shots=('player', 'count'),avg_xG=('xG', 'mean')).reset_index()
player_shot_stats.sort_values(by='total_shots', ascending=False)

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 8))

# Bar plot for total shots
ax1.bar(player_shot_stats['player'], player_shot_stats['total_shots'], color='b', alpha=0.6, label='Total Shots')
ax1.set_xlabel('Player')
ax1.set_ylabel('Total Shots')
ax1.tick_params(axis='y', labelcolor='b')
ax1.set_xticklabels(player_shot_stats['player'], rotation=45, ha='right')

# Line plot for average xG
ax2 = ax1.twinx()
ax2.plot(player_shot_stats['player'], player_shot_stats['avg_xG'], color='r', marker='o', label='Average xG')
ax2.tick_params(axis='y', labelcolor='r')

# Title and legends
plt.title('Total Shots and Average xG per Player')
fig.tight_layout()
fig.legend(loc='upper right', bbox_to_anchor=(0.9, 0.9))

# Display the plot
plt.show()

# %% [markdown]
# ### Assists

# %%
# Assists per player
player_assists = df_shots.groupby('player_assisted').size().reset_index(name='assists')
player_assists = player_assists.sort_values(by='assists', ascending=False)

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

# Bar plot for assists
ax.bar(player_assists['player_assisted'], player_assists['assists'], color='purple', alpha=0.6)
ax.set_xlabel('Player')
ax.set_ylabel('Assists')
ax.set_title('Assists per Player')
ax.set_xticklabels(player_assists['player_assisted'], rotation=45, ha='right')

# Display the plot
plt.show()

# %%
# Distribution of shotType
shot_type_distribution = df_shots['shotType'].value_counts().reset_index()
shot_type_distribution.columns = ['shotType', 'count']

# Plotting
fig, ax = plt.subplots(figsize=(12, 8))

# Bar plot for shotType distribution
ax.bar(shot_type_distribution['shotType'], shot_type_distribution['count'], color='orange', alpha=0.6)
ax.set_xlabel('Shot Type')
ax.set_ylabel('Count')
ax.set_title('Distribution of Shot Types')
ax.set_xticklabels(shot_type_distribution['shotType'], ha='right')

# Display the plot
plt.show()
